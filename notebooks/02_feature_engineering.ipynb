# %% [markdown]
# # Feature Engineering
#
# Build the six posture features and write the unified training dataset.

# %%
from pathlib import Path
import sys

ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))

from backend.services.features import FEATURE_COLUMNS
from scripts.build_dataset import build_dataset

print(FEATURE_COLUMNS)

# %%
dataset_path = ROOT / 'data' / 'processed' / 'dataset_final.csv'
df = build_dataset(dataset_path)
print(dataset_path)
print(df.shape)
display(df.head())
display(df['source'].value_counts())
display(df['label'].value_counts())

# %%
display(df[FEATURE_COLUMNS].describe().T)
